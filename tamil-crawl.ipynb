# %%
# !pip install wefe
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wefe
#   Downloading wefe-0.4.1-py3-none-any.whl (7.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 39.6 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from wefe) (1.16.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from wefe) (1.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from wefe) (4.65.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from wefe) (1.10.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from wefe) (1.22.4)
# Collecting semantic-version
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from wefe) (2.27.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from wefe) (1.5.3)
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (from wefe) (4.3.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from wefe) (5.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim->wefe) (6.3.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->wefe) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->wefe) (2.8.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->wefe) (8.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->wefe) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->wefe) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->wefe) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->wefe) (2.0.12)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->wefe) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->wefe) (1.2.0)
# Installing collected packages: semantic-version, wefe
# Successfully installed semantic-version-2.10.0 wefe-0.4.1

# %%
from wefe.query import Query
from wefe.word_embedding_model import WordEmbeddingModel
from wefe.metrics import WEAT, RNSB
from wefe.utils import run_queries
from wefe.datasets import load_weat
from gensim.models.keyedvectors import KeyedVectors
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #LOAD THE WORD VECTOR

# %%
w2v_embeddings = KeyedVectors.load_word2vec_format("/content/drive/MyDrive/fp/cc.ta.300.vec")
fasttextcc = WordEmbeddingModel(w2v_embeddings, 'fasttextcc')

# %% [markdown]
# # **WEAT**

# %%
from wefe.utils import run_queries

query = Query(
              target_sets = [['பெண்', 'அம்மா', 'ராணி', 'மகள்', 'தாய்', 'தலைவி ', 'அக்கா', 'அவள்'],
                             ['ஆண்', 'அப்பா', 'ராஜா', 'மகன்', 'தந்தை', 'தலைவன்', 'அண்ணா', 'அவன்']
                             ],          
              attribute_sets =[['வீடு', 'பெற்றோர்', 'குழந்தைகள்', 'குடும்பம்', 'உறவினர்கள்', 'திருமணம்'],
                               ['நிர்வாகி', 'மேலாண்மை', 'தொழில்முறை', 'நிறுவனம்', 'சம்பளம்', 'அலுவலகம்'],
                              ],
              target_sets_names = ['Female Terms', 'Male Terms'],
              attribute_sets_names = ['Family', 'Career'],
)

query2 = Query(
            target_sets = [['பெண்', 'அம்மா', 'ராணி', 'மகள்', 'தாய்'],['ஆண்', 'அப்பா', 'ராஜா', 'மகன்', 'தந்தை']],
              attribute_sets =[['செவிலியர்', 'ஒப்பனையாளர்', 'நடனமாடுபவர்', 'கைவினை', 'பணிப்பெண்'],
                               ['மருத்துவர்', 'பொறியாளர்', 'காவல்', 'சிப்பாய்','வேட்டைக்காரன்'],
                              ],
              target_sets_names = ['Female Terms', 'Male Terms'],
              attribute_sets_names = ['F_Professions','M_Professions'],
)

query3 = Query(
    
              target_sets = [['பெண்', 'அம்மா', 'ராணி', 'மகள்', 'தாய்', 'தலைவி ', 'அக்கா', 'அவள்'],
                             ['ஆண்', 'அப்பா', 'ராஜா', 'மகன்', 'தந்தை', 'தலைவன்', 'அண்ணா', 'அவன்']
                             ],
              attribute_sets =[['கவிதை', 'கலை', 'நடனம்', 'இலக்கியம்', 'நாவல்', 'சிம்பொனி', 'நாடகம்', 'சிற்பம்'],
                               ['கணிதம்', 'இயற்கணிதம்', 'வடிவியல்', 'கால்குலஸ்', 'சமன்பாடுகள்', 'கணக்கீடு', 'எண்கள்', 'கூட்டல்'],
                              ],
              target_sets_names = ['Female Terms', 'Male Terms'],
              attribute_sets_names = ['Arts','Maths'],    
)


queries= [query,query2,query3]
WEAT_gender_results = run_queries(
    WEAT, queries, [fasttextcc], queries_set_name="Gender Queries", metric_params={ "return_effect_size": True}
)
print(WEAT_gender_results)
# Out:
# query_name  Female Terms and Male Terms wrt Family and Career  \
# model_name
# fasttextcc                                           0.881197
#
# query_name  Female Terms and Male Terms wrt F_Professions and M_Professions  \
# model_name
# fasttextcc                                           1.069602
#
# query_name  Female Terms and Male Terms wrt Arts and Maths
# model_name
# fasttextcc                                          0.5891

# %% [markdown]
# # **RND**

# %%
from wefe.metrics import RND
qquery = Query(
                target_sets = [['பெண்', 'அம்மா', 'ராணி', 'மகள்', 'தாய்', 'தலைவி'],['ஆண்', 'அப்பா', 'ராஜா', 'மகன்', 'தந்தை', 'தலைவன்']],
              attribute_sets =[['வீடு', 'பெற்றோர்', 'குழந்தைகள்', 'குடும்பம்', 'உறவினர்கள்', 'திருமணம்'],],
              target_sets_names = ['Female Terms', 'Male Terms'],
              attribute_sets_names = ['Family'],
)

qquery2 = Query(
            target_sets = [['பெண்', 'அம்மா', 'ராணி', 'மகள்', 'தாய்', 'தலைவி'],['ஆண்', 'அப்பா', 'ராஜா', 'மகன்', 'தந்தை', 'தலைவன்']],
              attribute_sets =[['செவிலியர்', 'ஒப்பனையாளர்', 'நடனமாடுபவர்', 'கைவினை', 'பணிப்பெண்'],],
              target_sets_names = ['Female Terms', 'Male Terms'],
              attribute_sets_names = ['F_Professions'],
)

qquery3 = Query(
    
              target_sets = [['பெண்', 'அம்மா', 'ராணி', 'மகள்', 'தாய்', 'தலைவி'],['ஆண்', 'அப்பா', 'ராஜா', 'மகன்', 'தந்தை', 'தலைவன்']],
              attribute_sets =[['கவிதை', 'கலை', 'நடனம்', 'இலக்கியம்', 'நாவல்', 'சிம்பொனி', 'நாடகம்', 'சிற்பம்'],],
              target_sets_names = ['Female Terms', 'Male Terms'],
              attribute_sets_names = ['Arts'],


    
)

qqueries= [qquery,qquery2,qquery3]
RND_gender_results = run_queries(
    RND, qqueries, [fasttextcc], queries_set_name="Gender Queries"
)
print(RND_gender_results)
# Out:
# query_name  Female Terms and Male Terms wrt Family  \
# model_name
# fasttextcc                                0.045598
#
# query_name  Female Terms and Male Terms wrt F_Professions  \
# model_name
# fasttextcc                                       0.017448
#
# query_name  Female Terms and Male Terms wrt Arts
# model_name
# fasttextcc                               0.02782

# %% [markdown]
# # **ECT**

# %%
from wefe.metrics import ECT
qquery = Query(
                target_sets = [['பெண்', 'அம்மா', 'ராணி', 'மகள்', 'தாய்', 'தலைவி'],['ஆண்', 'அப்பா', 'ராஜா', 'மகன்', 'தந்தை', 'தலைவன்']],
              attribute_sets =[['வீடு', 'பெற்றோர்', 'குழந்தைகள்', 'குடும்பம்', 'உறவினர்கள்', 'திருமணம்'],],
              target_sets_names = ['Female Terms', 'Male Terms'],
              attribute_sets_names = ['Family'],
)

qquery2 = Query(
            target_sets = [['பெண்', 'அம்மா', 'ராணி', 'மகள்', 'தாய்', 'தலைவி'],['ஆண்', 'அப்பா', 'ராஜா', 'மகன்', 'தந்தை', 'தலைவன்']],
              attribute_sets =[['செவிலியர்', 'ஒப்பனையாளர்', 'நடனமாடுபவர்', 'கைவினை', 'பணிப்பெண்'],],
              target_sets_names = ['Female Terms', 'Male Terms'],
              attribute_sets_names = ['F_Professions'],
)

qquery3 = Query(
    
              target_sets = [['பெண்', 'அம்மா', 'ராணி', 'மகள்', 'தாய்', 'தலைவி'],['ஆண்', 'அப்பா', 'ராஜா', 'மகன்', 'தந்தை', 'தலைவன்']],
              attribute_sets =[['கவிதை', 'கலை', 'நடனம்', 'இலக்கியம்', 'நாவல்', 'சிம்பொனி', 'நாடகம்', 'சிற்பம்'],],
              target_sets_names = ['Female Terms', 'Male Terms'],
              attribute_sets_names = ['Arts'],


    
)

qqueries= [qquery,qquery2,qquery3]
ECT_gender_results = run_queries(
    ECT, qqueries, [fasttextcc], queries_set_name="Gender Queries"
)
print(ECT_gender_results)
# Out:
# query_name  Female Terms and Male Terms wrt Family  \
# model_name
# fasttextcc                                0.828571
#
# query_name  Female Terms and Male Terms wrt F_Professions  \
# model_name
# fasttextcc                                            0.8
#
# query_name  Female Terms and Male Terms wrt Arts
# model_name
# fasttextcc                              0.619048

# %% [markdown]
# # **DEBIAS**

# %%
from wefe.datasets import fetch_debiaswe
from wefe.debias.hard_debias import HardDebias

debiaswe_wordsets = fetch_debiaswe()

definitional_pairs = [['பெண்','ஆண்'],['அவள்','அவன்'], ['அம்மா','அப்பா'], ['மகள்','மகன்'], ['திருமதி','திரு'] ]

equalize_pairs = [['மடம்', 'கான்வென்ட்'], ['பூசாரி', 'கன்னியாஸ்திரி'], ['அப்பா', 'அம்மா'],['ஆண்கள்', 'பெண்கள்'], ['தாத்தா', 'பாட்டி'], ['பேரன்கள்', 'பேத்திகள்'],
['மாமா', 'அத்தை'], ['மனைவிகள்', 'கணவர்கள்'], ['அவன்', 'அவள்'], ['பையன்', 'பெண்'], ['சிறுவர்கள்', 'பெண்கள்'], ['சகோதரன்', 'சகோதரி'], ['சகோதரர்கள்', 'சகோதரிகள்'], ['அப்பாக்கள்', 'அம்மாக்கள்'], ['தந்தைமை', 'தாய்மை'],
['அப்பா', 'அம்மா'], ['ராஜா', 'ராணி'], ['ராஜாக்கள்', 'ராணிகள்'], ['ஆண்', 'பெண்'], ['ஆண்கள்', 'பெண்கள்'], ['மருமகன்', 'மருமகள்'], ['இளவரசன்', 'இளவரசி'], 
['மகன்', 'மகள்'], ['மகன்கள்', 'மகள்கள்'], ['இரட்டை_சகோதரன்', 'இரட்டை_சகோதரி']]


gender_specific =['அவன்', 'அவள்','பெண்கள்', 'ஆண்கள்', 'அவரது', 'பெண்','மனைவி', 'தன்னை', 'அம்மா', 'அப்பா', 'தலைவர்', 'மகள்', 'கணவன்', 'பையன்', 
                  'ராஜா', 'சிறுவர்கள்', 'சகோதரன்', 'பேச்சாளர்', 'சகோதரி', 'ஆண்', 'சிங்கங்கள் ', 'சகோதரர்கள்', 'நடிகை', 'மகன்கள்', 'காதலி', 'ராஜாக்கள்', 'மகள்கள்', 'இளவரசன்', 'ராணி',
                  'காளைகள்', 'காதலன்', 'சகோதரிகள்', 'அம்மாக்கள்', 'சார்', 'தொழிலதிபர்', 'பாட்டி', 'தாத்தா', 'மான்', 'மாமா', 'ராணிகள்', 'பேரன்', 'இரட்டையர்கள்',
                  'மனைவிகள்', 'விதவை', 'மருமகன்', 'மணமகள்', 'தந்தைகள்', 'கன்னி', 'பேத்தி', 'பேத்திகள்', 'பேரன்கள்', 'இளங்கலை', 'கணவர்கள்', 'தாடி', 'மாற்றாந்தாய்']
            
print(f"definitional_pairs: \n{definitional_pairs}")
print(f"equalize_pairs: \n{equalize_pairs}")
print(f"gender_specific: \n{gender_specific}")
print("-" * 70, "\n")
# Out:
# definitional_pairs:
# [['பெண்', 'ஆண்'], ['அவள்', 'அவன்'], ['அம்மா', 'அப்பா'], ['மகள்', 'மகன்'], ['திருமதி', 'திரு']]
# equalize_pairs:
# [['மடம்', 'கான்வென்ட்'], ['பூசாரி', 'கன்னியாஸ்திரி'], ['அப்பா', 'அம்மா'], ['ஆண்கள்', 'பெண்கள்'], ['தாத்தா', 'பாட்டி'], ['பேரன்கள்', 'பேத்திகள்'], ['மாமா', 'அத்தை'], ['மனைவிகள்', 'கணவர்கள்'], ['அவன்', 'அவள்'], ['பையன்', 'பெண்'], ['சிறுவர்கள்', 'பெண்கள்'], ['சகோதரன்', 'சகோதரி'], ['சகோதரர்கள்', 'சகோதரிகள்'], ['அப்பாக்கள்', 'அம்மாக்கள்'], ['தந்தைமை', 'தாய்மை'], ['அப்பா', 'அம்மா'], ['ராஜா', 'ராணி'], ['ராஜாக்கள்', 'ராணிகள்'], ['ஆண்', 'பெண்'], ['ஆண்கள்', 'பெண்கள்'], ['மருமகன்', 'மருமகள்'], ['இளவரசன்', 'இளவரசி'], ['மகன்', 'மகள்'], ['மகன்கள்', 'மகள்கள்'], ['இரட்டை_சகோதரன்', 'இரட்டை_சகோதரி']]
# gender_specific:
# ['அவன்', 'அவள்', 'பெண்கள்', 'ஆண்கள்', 'அவரது', 'பெண்', 'மனைவி', 'தன்னை', 'அம்மா', 'அப்பா', 'தலைவர்', 'மகள்', 'கணவன்', 'பையன்', 'ராஜா', 'சிறுவர்கள்', 'சகோதரன்', 'பேச்சாளர்', 'சகோதரி', 'ஆண்', 'சிங்கங்கள் ', 'சகோதரர்கள்', 'நடிகை', 'மகன்கள்', 'காதலி', 'ராஜாக்கள்', 'மகள்கள்', 'இளவரசன்', 'ராணி', 'காளைகள்', 'காதலன்', 'சகோதரிகள்', 'அம்மாக்கள்', 'சார்', 'தொழிலதிபர்', 'பாட்டி', 'தாத்தா', 'மான்', 'மாமா', 'ராணிகள்', 'பேரன்', 'இரட்டையர்கள்', 'மனைவிகள்', 'விதவை', 'மருமகன்', 'மணமகள்', 'தந்தைகள்', 'கன்னி', 'பேத்தி', 'பேத்திகள்', 'பேரன்கள்', 'இளங்கலை', 'கணவர்கள்', 'தாடி', 'மாற்றாந்தாய்']
# ----------------------------------------------------------------------

# %%
hd = HardDebias(verbose=False, criterion_name="gender")
hd.fit(
    fasttextcc, definitional_pairs=definitional_pairs, equalize_pairs=equalize_pairs,
)
gender_debiased_model = hd.transform(fasttextcc, ignore=gender_specific, copy=True)
# Out:
# Copy argument is True. Transform will attempt to create a copy of the original model. This may fail due to lack of memory.
# Model copy created successfully.
# WARNING:gensim.models.keyedvectors:destructive init_sims(replace=True) deprecated & no longer required for space-efficiency
# 100%|██████████| 2000000/2000000 [00:46<00:00, 43092.84it/s]
# WARNING:gensim.models.keyedvectors:destructive init_sims(replace=True) deprecated & no longer required for space-efficiency
# WARNING:gensim.models.keyedvectors:destructive init_sims(replace=True) deprecated & no longer required for space-efficiency

# %% [markdown]
# # **DEBIAS - MEASURING AGAINST WEAT**

# %%
WEAT_gender_results = run_queries(
    WEAT, queries, [fasttextcc,gender_debiased_model], queries_set_name="Gender Queries"
)
WEAT_eff = run_queries(
    WEAT, queries, [fasttextcc,gender_debiased_model ], queries_set_name="Gender Queries",
    metric_params={ "return_effect_size": True},  

)
#print(WEAT_gender_results)
print(WEAT_eff)
# Out:
# query_name                  Female Terms and Male Terms wrt Family and Career  \
# model_name
# fasttextcc                                                           0.881197
# fasttextcc_gender_debiased                                           0.490329
#
# query_name                  Female Terms and Male Terms wrt F_Professions and M_Professions  \
# model_name
# fasttextcc                                                           1.069602
# fasttextcc_gender_debiased                                          -0.038711
#
# query_name                  Female Terms and Male Terms wrt Arts and Maths
# model_name
# fasttextcc                                                        0.589100
# fasttextcc_gender_debiased                                        0.257146

# %% [markdown]
# # **DEBIAS - MEASURING AGAINST RND**

# %%
queries= [qquery,qquery2,qquery3]
RND_gender_results = run_queries(
    RND, queries, [fasttextcc, gender_debiased_model ], queries_set_name="Gender Queries"
)
print(RND_gender_results)
# Out:
# query_name                  Female Terms and Male Terms wrt Family  \
# model_name
# fasttextcc                                                0.045598
# fasttextcc_gender_debiased                                0.005945
#
# query_name                  Female Terms and Male Terms wrt F_Professions  \
# model_name
# fasttextcc                                                       0.017448
# fasttextcc_gender_debiased                                       0.001716
#
# query_name                  Female Terms and Male Terms wrt Arts
# model_name
# fasttextcc                                              0.027820
# fasttextcc_gender_debiased                             -0.005555

# %% [markdown]
# # **DEBIAS - MEASURING AGAINST ECT**

# %%
queries= [qquery,qquery2,qquery3]
ECT_gender_results = run_queries(
    ECT, queries, [fasttextcc, gender_debiased_model], queries_set_name="Gender Queries"
)
print(ECT_gender_results)
# Out:
# query_name                  Female Terms and Male Terms wrt Family  \
# model_name
# fasttextcc                                                0.828571
# fasttextcc_gender_debiased                                0.828571
#
# query_name                  Female Terms and Male Terms wrt F_Professions  \
# model_name
# fasttextcc                                                            0.8
# fasttextcc_gender_debiased                                            1.0
#
# query_name                  Female Terms and Male Terms wrt Arts
# model_name
# fasttextcc                                              0.619048
# fasttextcc_gender_debiased                              0.952381

# %% [markdown]
# # **VISUALIZATION**

# %%
import matplotlib.pyplot as plt

# x1 = [1, 3, 5]
# # y1 = [weat biased familycareer, weat biased profs, weat biased matharts]
# y1 = [0.393, 0.528, 0.061]

# x2 = [2, 4, 6]
# # y2 = [weat debiased familycareer, weat debiased profs, weat debiased matharts]
# y2 = [0.182, 0.362, 0.022]

x1 = np.array(["Car_Fam_b"])
y1 = [0.343]

x2 = np.array(["Car_Fam_db"])
y2 = [0.122]

x3 = np.array(["Profs_b"])
y3 = [0.295]

x4 = np.array(["Profs_db"])
y4 = [-0.075]

x5 = np.array(["Math_Art_b"])
y5 = [0.130]

x6 = np.array(["Math_Art_db"])
y6 = [0.021]

# Colors: https://matplotlib.org/api/colors_api.html

plt.bar(x1, y1, label="fasttextcc model ", color='r') #rnd biased - b, c #ect biased - m, g
plt.bar(x2, y2, label="gender_debiased_model", color='y')
plt.bar(x3, y3, color='r')
plt.bar(x4, y4, color='y')
plt.bar(x5, y5, color='r')
plt.bar(x6, y6, color='y')
plt.plot()

plt.xlabel("QUERIES")
plt.ylabel("BIAS MEASURE")
plt.title("WEAT SCORES -cc.ta.300.vec - Before and After debiasing")
plt.legend()
plt.show()

# %%
x1 = np.array(["Car_Fam_b"])
y1 = [0.82]

x2 = np.array(["Car_Fam_db"])
y2 = [0.82]

x3 = np.array(["Profs_b"])
y3 = [0.8]

x4 = np.array(["Profs_db"])
y4 = [1]

x5 = np.array(["Math_Art_b"])
y5 = [0.6]

x6 = np.array(["Math_Art_db"])
y6 = [0.9]


plt.bar(x1, y1, label="fasttextcc model ", color='m') #rnd biased - b, c #ect biased - m, g
plt.bar(x2, y2, label="gender_debiased_model", color='g')
plt.bar(x3, y3, color='m')
plt.bar(x4, y4, color='g')
plt.bar(x5, y5, color='m')
plt.bar(x6, y6, color='g')
plt.plot()

plt.xlabel("QUERIES")
plt.ylabel("BIAS MEASURE")
plt.title("ECT SCORES - cc.ta.300.vec - Before and After debiasing")
plt.legend()
plt.show()

# %%
x1 = np.array(["Car_Fam_b"])
y1 = [0.045]

x2 = np.array(["Car_Fam_db"])
y2 = [0.005]

x3 = np.array(["Profs_b"])
y3 = [0.017]

x4 = np.array(["Profs_db"])
y4 = [0.0017]

x5 = np.array(["Math_Art_b"])
y5 = [0.027]

x6 = np.array(["Math_Art_db"])
y6 = [-0.005]


plt.bar(x1, y1, label="fasttextcc model ", color='b') #rnd biased - b, c #ect biased - m, g
plt.bar(x2, y2, label="gender_debiased_model", color='c')
plt.bar(x3, y3, color='b')
plt.bar(x4, y4, color='c')
plt.bar(x5, y5, color='b')
plt.bar(x6, y6, color='c')
plt.plot()

plt.xlabel("QUERIES")
plt.ylabel("BIAS MEASURE")
plt.title("RND SCORES - cc.ta.300.vec - Before and After debiasing")
plt.legend()
plt.show()
